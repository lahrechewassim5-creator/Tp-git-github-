# %% [markdown]
# <a href="https://colab.research.google.com/github/lahrechewassim5-creator/Tp-git-github-/blob/main/GIT_GITHUB_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p mon_projet
# %cd mon_projet
# !echo "Bonjour Git et GitHub depuis Colab" > texte.txt
# Out:
# /content/mon_projet/mon_projet

# %%
# 1️⃣ Initialiser le dépôt Git directement avec la branche 'main'
# !git init -b main
# Out:
# Initialized empty Git repository in /content/mon_projet/mon_projet/.git/

# %%
# 2️⃣ Configurer Git (nom et e-mail)
# !git config user.name "Lahreche mohamed ouassim"
# !git config user.email "lahrechewassim5@gmail.com"

# %%
# 3️⃣ Ajouter les fichiers et créer un commit
# !git add .
# !git commit -m "deuxiéme commit depuis Colab"
# Out:
# [main (root-commit) 6c07d4f] Premier commit depuis Colab
#  1 file changed, 1 insertion(+)
#  create mode 100644 texte.txt

# %%
# 4️⃣ Ajouter le dépôt distant avec ton token GitHub
from getpass import getpass
import os
token = getpass('Entre ton GitHub token : ')
os.environ['GITHUB_TOKEN'] = token
# !git remote add origin https://$GITHUB_TOKEN@github.com/lahreche mohamed ouasssim/mon_projet_colab.git
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1652948525.py in <cell line: 0>()
#       2 from getpass import getpass
#       3 import os
# ----> 4 token = getpass('Entre ton GitHub token : ')
#       5 os.environ['GITHUB_TOKEN'] = token
#       6 get_ipython().system('git remote add origin https://$GITHUB_TOKEN@github.com/lahreche mohamed ouasssim/mon_projet_colab.git')
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#    1157                 stacklevel=2,
#    1158             )
# -> 1159         return self._input_request(
#    1160             prompt,
#    1161             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
# 🚀 Forcer l'envoi et écraser le contenu distant
# !git push origin main --force
# Out:
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 260 bytes | 260.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/KhoualdiTaki/mon_projet_colab.git
#  + a4869f7...6c07d4f main -> main (forced update)
